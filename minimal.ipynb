# %%
from ems.run import Driver
driver = Driver('examples/minimal.yaml')
sim, data = driver.create_simulator()

# %%
sim.run()
# Out:
# Current Time: 2019-01-31 00:12:02.100000
# Processing new case: 1
# Selected ambulance: 2
# Started new event: Heading to Incident
# Destination: 32.865867173801504, -117.2403117032452
# Duration: 0:12:15
# Distance Accuracy: None
# Busy ambulances: ['2']
# Ongoing cases: [1]
# Pending cases: []
#
# Metrics
# ...
# Current Time: 2019-01-31 00:24:17.100000
# Processing ongoing case: 1
# Finished event: Heading to Incident
# Started new event: Attending to Incident
# Destination: 32.865867173801504, -117.2403117032452
# Duration: 0:14:10
# Distance Difference: None
# Busy ambulances: ['2']
# Ongoing cases: [1]
# Pending cases: []
#
# Metrics
# ...
# Current Time: 2019-01-31 00:25:33.100000
# Processing new case: 2
# Selected ambulance: 0
# Started new event: Heading to Incident
# Destination: 32.884565147677144, -117.25031243741249
# Duration: 0:18:07
# Distance Accuracy: None
# Busy ambulances: ['0', '2']
# Ongoing cases: [1, 2]
# Pending cases: []
#
# Metrics
# ...
