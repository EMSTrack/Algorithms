# %%
# %matplotlib inline
import argparse

from ems.algorithms.analysis.analyze_percent_coverage import AnalyzePercentCoverage
from ems.algorithms.selection.dispatch_fastest_ambulance import BestTravelTimeAlgorithm
from ems.data.filters import kmeans_select_bases
from ems.data.tijuana import CSVTijuanaDataset
from ems.models.ambulance import Ambulance
from ems.settings import Settings
from ems.simulators.dispatcher_simulator import DispatcherSimulator

def go(settings:str="small_hans", ambulances:int = 7, bases:int = 7):

    clargs = argparse.Namespace(settings=settings, ambulances = ambulances, bases = bases)

    # Initialize settings
    settings = Settings(debug=True,
                        args=clargs
                       )

    # Initialize dataset
    dataset = CSVTijuanaDataset(demands_file_path=settings.demands_file,
                                bases_file_path=settings.bases_file,
                                cases_file_path=settings.cases_file,
                                travel_times_file_path=settings.travel_times_file)

    # Initialize ambulance_selection
    ambulance_select = BestTravelTimeAlgorithm(travel_times=dataset.travel_times)

    # Initialize demand_coverage
    determine_coverage = []
    determine_coverage.append(AnalyzePercentCoverage(travel_times=dataset.travel_times))

    # Select bases
    chosen_base_locations = kmeans_select_bases(dataset.bases, dataset.travel_times)

    # Generate ambulances - random base placement (may want to abstract into function)
    ambulances = []
    for index in range(settings.num_ambulances):
        ambulance = Ambulance(id=index,
                              base=chosen_base_locations[index],
                              location=chosen_base_locations[index])
        ambulances.append(ambulance)

    # Initialize the simulator
    sim = DispatcherSimulator(ambulances=ambulances,
                              cases=dataset.cases,
                              ambulance_selector=ambulance_select,
                              coverage_alg=determine_coverage,
                              plot=settings.plot
                              )

    # Start the whole thing
    finished_cases = sim.run()

# %%
go(settings="small_hans", ambulances = 3, bases = 3)
# Out:
# Default init_bases(): Kmeans init bases
# ========================================================================
#
# Current Time: 2014-01-01 00:21:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 36 which was recorded at 2014-01-01 00:21:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 00:21:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 00:59:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-01 00:59:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 06:51:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 5 which was recorded at 2014-01-01 06:51:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 06:51:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 07:10:00
# Current Event: Start Case
# Coverage: 43.0 %.
# Starting case 37 which was recorded at 2014-01-01 07:10:00
# Ambulance 1 chosen with one-way travel time 0:18:05 (total duration: 0 days 00:56:10)
# Deploying ambulance 1 at time 2014-01-01 07:10:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 07:29:00
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 0 at time 2014-01-01 07:29:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 08:01:00
# Current Event: Start Case
# Coverage: 46.0 %.
# Starting case 26 which was recorded at 2014-01-01 08:01:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 08:01:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 08:06:10
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 1 at time 2014-01-01 08:06:10
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 08:36:00
# Current Event: Start Case
# Coverage: 43.0 %.
# Starting case 6 which was recorded at 2014-01-01 08:36:00
# Ambulance 1 chosen with one-way travel time 0:18:05 (total duration: 0 days 00:56:10)
# Deploying ambulance 1 at time 2014-01-01 08:36:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 08:39:00
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 0 at time 2014-01-01 08:39:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 09:14:00
# Current Event: Start Case
# Coverage: 46.0 %.
# Starting case 29 which was recorded at 2014-01-01 09:14:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 09:14:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 09:32:10
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 1 at time 2014-01-01 09:32:10
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 09:45:00
# Current Event: Start Case
# Coverage: 43.0 %.
# Starting case 22 which was recorded at 2014-01-01 09:45:00
# Ambulance 1 chosen with one-way travel time 0:18:05 (total duration: 0 days 00:56:10)
# Deploying ambulance 1 at time 2014-01-01 09:45:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 09:52:00
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 0 at time 2014-01-01 09:52:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 10:30:00
# Current Event: Start Case
# Coverage: 46.0 %.
# Starting case 7 which was recorded at 2014-01-01 10:30:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 10:30:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 10:41:10
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 1 at time 2014-01-01 10:41:10
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 11:08:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-01 11:08:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 11:30:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 32 which was recorded at 2014-01-01 11:30:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 11:30:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 12:08:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-01 12:08:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 12:53:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 8 which was recorded at 2014-01-01 12:53:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 12:53:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 13:31:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-01 13:31:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 13:54:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 9 which was recorded at 2014-01-01 13:54:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 13:54:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 14:32:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-01 14:32:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 15:45:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 10 which was recorded at 2014-01-01 15:45:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 15:45:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 16:12:00
# Current Event: Start Case
# Coverage: 43.0 %.
# Starting case 11 which was recorded at 2014-01-01 16:12:00
# Ambulance 1 chosen with one-way travel time 0:18:05 (total duration: 0 days 00:56:10)
# Deploying ambulance 1 at time 2014-01-01 16:12:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 16:23:00
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 0 at time 2014-01-01 16:23:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 17:08:10
# Current Event: Retire Ambulance
# Coverage: 46.0 %.
# Retiring ambulance 1 at time 2014-01-01 17:08:10
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 17:24:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 12 which was recorded at 2014-01-01 17:24:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 17:24:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:01:00
# Current Event: Start Case
# Coverage: 43.0 %.
# Starting case 23 which was recorded at 2014-01-01 18:01:00
# Ambulance 1 chosen with one-way travel time 0:18:05 (total duration: 0 days 00:56:10)
# Deploying ambulance 1 at time 2014-01-01 18:01:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:02:00
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 0 at time 2014-01-01 18:02:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:33:00
# Current Event: Start Case
# Coverage: 46.0 %.
# Starting case 13 which was recorded at 2014-01-01 18:33:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 18:33:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:57:10
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 1 at time 2014-01-01 18:57:10
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 19:11:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-01 19:11:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 19:39:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 14 which was recorded at 2014-01-01 19:39:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 19:39:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 20:03:00
# Current Event: Start Case
# Coverage: 43.0 %.
# Starting case 27 which was recorded at 2014-01-01 20:03:00
# Ambulance 1 chosen with one-way travel time 0:21:11 (total duration: 0 days 01:02:22)
# Deploying ambulance 1 at time 2014-01-01 20:03:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 20:17:00
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 0 at time 2014-01-01 20:17:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 21:05:22
# Current Event: Retire Ambulance
# Coverage: 46.0 %.
# Retiring ambulance 1 at time 2014-01-01 21:05:22
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 21:27:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 31 which was recorded at 2014-01-01 21:27:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 21:27:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 21:50:00
# Current Event: Start Case
# Coverage: 43.0 %.
# Starting case 15 which was recorded at 2014-01-01 21:50:00
# Ambulance 1 chosen with one-way travel time 0:18:05 (total duration: 0 days 00:56:10)
# Deploying ambulance 1 at time 2014-01-01 21:50:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 22:05:00
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 0 at time 2014-01-01 22:05:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 22:46:10
# Current Event: Retire Ambulance
# Coverage: 46.0 %.
# Retiring ambulance 1 at time 2014-01-01 22:46:10
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 00:05:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 38 which was recorded at 2014-01-02 00:05:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 00:05:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 00:43:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-02 00:43:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 01:15:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 28 which was recorded at 2014-01-02 01:15:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 01:15:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 01:52:00
# Current Event: Start Case
# Coverage: 43.0 %.
# Starting case 18 which was recorded at 2014-01-02 01:52:00
# Ambulance 1 chosen with one-way travel time 0:18:05 (total duration: 0 days 00:56:10)
# Deploying ambulance 1 at time 2014-01-02 01:52:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 01:53:00
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 0 at time 2014-01-02 01:53:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 02:48:10
# Current Event: Retire Ambulance
# Coverage: 46.0 %.
# Retiring ambulance 1 at time 2014-01-02 02:48:10
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 05:59:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 19 which was recorded at 2014-01-02 05:59:00
# Ambulance 1 chosen with one-way travel time 0:07:33 (total duration: 0 days 00:35:06)
# Deploying ambulance 1 at time 2014-01-02 05:59:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 06:34:06
# Current Event: Retire Ambulance
# Coverage: 46.0 %.
# Retiring ambulance 1 at time 2014-01-02 06:34:06
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 07:06:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 41 which was recorded at 2014-01-02 07:06:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 07:06:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 07:44:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-02 07:44:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 08:28:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 42 which was recorded at 2014-01-02 08:28:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 08:28:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 08:30:00
# Current Event: Start Case
# Coverage: 43.0 %.
# Starting case 40 which was recorded at 2014-01-02 08:30:00
# Ambulance 1 chosen with one-way travel time 0:18:05 (total duration: 0 days 00:56:10)
# Deploying ambulance 1 at time 2014-01-02 08:30:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 08:47:00
# Current Event: Start Case
# Coverage: 18.0 %.
# Starting case 30 which was recorded at 2014-01-02 08:47:00
# Ambulance 2 chosen with one-way travel time 0:31:34 (total duration: 0 days 01:23:08)
# Deploying ambulance 2 at time 2014-01-02 08:47:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 09:00:00
# Current Event: Delay Case
# Coverage: 0.0 %.
# No available ambulances to deal with incoming case: 21 at 2014-01-02 09:00:00
# Busy ambulances:  [0, 1, 2]
# Pending cases:  [21]
# ========================================================================
#
# Current Time: 2014-01-02 09:06:00
# Current Event: Retire Ambulance
# Coverage: 0.0 %.
# Retiring ambulance 0 at time 2014-01-02 09:06:00
# Busy ambulances:  [1, 2]
# Pending cases:  [21]
# ========================================================================
#
# Current Time: 2014-01-02 09:00:00
# Current Event: Start Case
# Coverage: 28.000000000000004 %.
# Starting case 21 which was recorded at 2014-01-02 09:00:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 09:00:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 09:26:10
# Current Event: Retire Ambulance
# Coverage: 0.0 %.
# Retiring ambulance 1 at time 2014-01-02 09:26:10
# Busy ambulances:  [0, 2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 09:38:00
# Current Event: Retire Ambulance
# Coverage: 27.0 %.
# Retiring ambulance 0 at time 2014-01-02 09:38:00
# Busy ambulances:  [2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 10:05:00
# Current Event: Start Case
# Coverage: 46.0 %.
# Starting case 44 which was recorded at 2014-01-02 10:05:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 10:05:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 10:10:08
# Current Event: Retire Ambulance
# Coverage: 27.0 %.
# Retiring ambulance 2 at time 2014-01-02 10:10:08
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 10:19:00
# Current Event: Start Case
# Coverage: 43.0 %.
# Starting case 24 which was recorded at 2014-01-02 10:19:00
# Ambulance 1 chosen with one-way travel time 0:18:05 (total duration: 0 days 00:56:10)
# Deploying ambulance 1 at time 2014-01-02 10:19:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 10:28:00
# Current Event: Start Case
# Coverage: 18.0 %.
# Starting case 25 which was recorded at 2014-01-02 10:28:00
# Ambulance 2 chosen with one-way travel time 0:31:34 (total duration: 0 days 01:23:08)
# Deploying ambulance 2 at time 2014-01-02 10:28:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 10:43:00
# Current Event: Retire Ambulance
# Coverage: 0.0 %.
# Retiring ambulance 0 at time 2014-01-02 10:43:00
# Busy ambulances:  [1, 2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 11:02:00
# Current Event: Start Case
# Coverage: 28.000000000000004 %.
# Starting case 43 which was recorded at 2014-01-02 11:02:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 11:02:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 11:15:10
# Current Event: Retire Ambulance
# Coverage: 0.0 %.
# Retiring ambulance 1 at time 2014-01-02 11:15:10
# Busy ambulances:  [0, 2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 11:40:00
# Current Event: Retire Ambulance
# Coverage: 27.0 %.
# Retiring ambulance 0 at time 2014-01-02 11:40:00
# Busy ambulances:  [2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 11:51:08
# Current Event: Retire Ambulance
# Coverage: 46.0 %.
# Retiring ambulance 2 at time 2014-01-02 11:51:08
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 12:21:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 45 which was recorded at 2014-01-02 12:21:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 12:21:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 12:59:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-02 12:59:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 14:20:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 39 which was recorded at 2014-01-02 14:20:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 14:20:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 14:58:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-02 14:58:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 15:02:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 46 which was recorded at 2014-01-02 15:02:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 15:02:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 15:40:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-02 15:40:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 16:00:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 33 which was recorded at 2014-01-02 16:00:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 16:00:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 16:38:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-02 16:38:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 17:36:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 35 which was recorded at 2014-01-02 17:36:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 17:36:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 18:14:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-02 18:14:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 18:43:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 47 which was recorded at 2014-01-02 18:43:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 18:43:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 19:12:00
# Current Event: Start Case
# Coverage: 43.0 %.
# Starting case 34 which was recorded at 2014-01-02 19:12:00
# Ambulance 1 chosen with one-way travel time 0:18:05 (total duration: 0 days 00:56:10)
# Deploying ambulance 1 at time 2014-01-02 19:12:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 19:21:00
# Current Event: Retire Ambulance
# Coverage: 18.0 %.
# Retiring ambulance 0 at time 2014-01-02 19:21:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 19:56:00
# Current Event: Start Case
# Coverage: 46.0 %.
# Starting case 49 which was recorded at 2014-01-02 19:56:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 19:56:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 19:59:00
# Current Event: Start Case
# Coverage: 18.0 %.
# Starting case 48 which was recorded at 2014-01-02 19:59:00
# Ambulance 2 chosen with one-way travel time 0:31:34 (total duration: 0 days 01:23:08)
# Deploying ambulance 2 at time 2014-01-02 19:59:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 20:08:10
# Current Event: Retire Ambulance
# Coverage: 0.0 %.
# Retiring ambulance 1 at time 2014-01-02 20:08:10
# Busy ambulances:  [0, 2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 20:34:00
# Current Event: Retire Ambulance
# Coverage: 27.0 %.
# Retiring ambulance 0 at time 2014-01-02 20:34:00
# Busy ambulances:  [2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 21:22:08
# Current Event: Retire Ambulance
# Coverage: 46.0 %.
# Retiring ambulance 2 at time 2014-01-02 21:22:08
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 23:43:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 17 which was recorded at 2014-01-02 23:43:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 23:43:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-03 00:21:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-03 00:21:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-28 09:40:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 3 which was recorded at 2014-01-28 09:40:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-28 09:40:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-28 10:18:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-28 10:18:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-28 15:45:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 2 which was recorded at 2014-01-28 15:45:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-28 15:45:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-28 16:23:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-28 16:23:00
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-28 18:45:00
# Current Event: Start Case
# Coverage: 62.0 %.
# Starting case 1 which was recorded at 2014-01-28 18:45:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-28 18:45:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-28 19:23:00
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 0 at time 2014-01-28 19:23:00
# The elems was [0.62, 0.43, 0.62, 0.43, 0.18, 0.46, 0.18, 0.43, 0.18, 0.46, 0.18, 0.43, 0.18, 0.46, 0.18, 0.43, 0.62, 0.43, 0.62, 0.43, 0.62, 0.43, 0.62, 0.43, 0.18, 0.46, 0.62, 0.43, 0.18, 0.46, 0.18, 0.43, 0.62, 0.43, 0.18, 0.46, 0.62, 0.43, 0.18, 0.46, 0.62, 0.43, 0.62, 0.43, 0.18, 0.46, 0.62, 0.46, 0.62, 0.43, 0.62, 0.43, 0.18, 0.0, 0.0, 0.28, 0.0, 0.27, 0.46, 0.27, 0.43, 0.18, 0.0, 0.28, 0.0, 0.27, 0.46, 0.62, 0.43, 0.62, 0.43, 0.62, 0.43, 0.62, 0.43, 0.62, 0.43, 0.62, 0.43, 0.18, 0.46, 0.18, 0.0, 0.27, 0.46, 0.62, 0.43, 0.62, 0.43, 0.62, 0.43, 0.62, 0.43].
# The max was 0.62.
# The min was 0.0.
# The mean was 0.40236559139784944.
# The median was 0.43.
# The mode was 0.43.
# The pstdev was 0.18150741475693777.
# The pvariance was 0.032944941611747026.
# The count was 93.
