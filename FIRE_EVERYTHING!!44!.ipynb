# %%
# %matplotlib inline
import argparse

from ems.algorithms.analysis.analyze_percent_coverage import AnalyzePercentCoverage
from ems.algorithms.selection.dispatch_fastest_ambulance import BestTravelTimeAlgorithm
from ems.data.filters import kmeans_select_bases
from ems.data.tijuana import CSVTijuanaDataset
from ems.models.ambulance import Ambulance
from ems.settings import Settings
from ems.simulators.dispatcher_simulator import DispatcherSimulator

def go(settings:str="small_hans", ambulances:int = 7, bases:int = 7):

    clargs = argparse.Namespace(settings=settings, ambulances = ambulances, bases = bases)

    # Initialize settings
    settings = Settings(debug=True,
                        args=clargs
                       )

    # Initialize dataset
    dataset = CSVTijuanaDataset(demands_file_path=settings.demands_file,
                                bases_file_path=settings.bases_file,
                                cases_file_path=settings.cases_file,
                                travel_times_file_path=settings.travel_times_file)

    # Initialize ambulance_selection
    ambulance_select = BestTravelTimeAlgorithm(travel_times=dataset.travel_times)

    # Initialize demand_coverage
    determine_coverage = []
    determine_coverage.append(AnalyzePercentCoverage(travel_times=dataset.travel_times))

    # Select bases
    chosen_base_locations = kmeans_select_bases(dataset.bases, dataset.travel_times)

    # Generate ambulances - random base placement (may want to abstract into function)
    ambulances = []
    for index in range(settings.num_ambulances):
        ambulance = Ambulance(id=index,
                              base=chosen_base_locations[index],
                              location=chosen_base_locations[index])
        ambulances.append(ambulance)

    # Initialize the simulator
    sim = DispatcherSimulator(ambulances=ambulances,
                              cases=dataset.cases,
                              ambulance_selector=ambulance_select,
                              coverage_alg=determine_coverage,
                              plot=settings.plot
                              )

    # Start the whole thing
    finished_cases = sim.run()

# %%
go(settings="hans_med", ambulances = 65, bases = 65)
# Out:
# Default init_bases(): Kmeans init bases
# ========================================================================
#
# Current Time: 2014-01-01 00:13:00
# Current Event: Start Case
# Coverage: 98.0 %.
# Starting case 138 which was recorded at 2014-01-01 00:13:00
# Ambulance 5 chosen with one-way travel time 0:09:42 (total duration: 0 days 00:39:24)
# Deploying ambulance 5 at time 2014-01-01 00:13:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [5]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 00:21:00
# Current Event: Start Case
# Coverage: 94.0 %.
# Starting case 36 which was recorded at 2014-01-01 00:21:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 00:21:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 5]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 00:46:00
# Current Event: Start Case
# Coverage: 78.0 %.
# Starting case 141 which was recorded at 2014-01-01 00:46:00
# Ambulance 14 chosen with one-way travel time 0:07:03 (total duration: 0 days 00:34:06)
# Deploying ambulance 14 at time 2014-01-01 00:46:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 5, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 00:52:24
# Current Event: Retire Ambulance
# Coverage: 78.0 %.
# Retiring ambulance 5 at time 2014-01-01 00:52:24
# Busy ambulances:  [0, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 00:59:00
# Current Event: Retire Ambulance
# Coverage: 82.0 %.
# Retiring ambulance 0 at time 2014-01-01 00:59:00
# Busy ambulances:  [14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 00:59:00
# Current Event: Start Case
# Coverage: 98.0 %.
# Starting case 109 which was recorded at 2014-01-01 00:59:00
# Ambulance 7 chosen with one-way travel time 0:05:47 (total duration: 0 days 00:31:34)
# Deploying ambulance 7 at time 2014-01-01 00:59:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [7, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 01:20:06
# Current Event: Retire Ambulance
# Coverage: 95.0 %.
# Retiring ambulance 14 at time 2014-01-01 01:20:06
# Busy ambulances:  [7]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 01:30:34
# Current Event: Retire Ambulance
# Coverage: 95.0 %.
# Retiring ambulance 7 at time 2014-01-01 01:30:34
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 01:51:00
# Current Event: Start Case
# Coverage: 98.0 %.
# Starting case
, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 17:56:00
# Current Event: Start Case
# Coverage: 95.0 %.
# Starting case 119 which was recorded at 2014-01-01 17:56:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 17:56:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:01:00
# Current Event: Start Case
# Coverage: 78.0 %.
# Starting case 23 which was recorded at 2014-01-01 18:01:00
# Ambulance 6 chosen with one-way travel time 0:14:11 (total duration: 0 days 00:48:22)
# Deploying ambulance 6 at time 2014-01-01 18:01:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 6, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:05:56
# Current Event: Retire Ambulance
# Coverage: 70.0 %.
# Retiring ambulance 3 at time 2014-01-01 18:05:56
# Busy ambulances:  [0, 6, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:27:22
# Current Event: Retire Ambulance
# Coverage: 76.0 %.
# Retiring ambulance 8 at time 2014-01-01 18:27:22
# Busy ambulances:  [0, 6]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:33:00
# Current Event: Start Case
# Coverage: 77.0 %.
# Starting case 13 which was recorded at 2014-01-01 18:33:00
# Ambulance 3 chosen with one-way travel time 0:10:58 (total duration: 0 days 00:41:56)
# Deploying ambulance 3 at time 2014-01-01 18:33:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 6]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:34:00
# Current Event: Retire Ambulance
# Coverage: 73.0 %.
# Retiring ambulance 0 at time 2014-01-01 18:34:00
# Busy ambulances:  [3, 6]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:37:00
# Current Event: Start Case
# Coverage: 90.0 %.
# Starting case 142 which was recorded at 2014-01-01 18:37:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 18:37:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 6]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:41:00
# Current Event: Start Case
# Coverage: 73.0 %.
# Starting case 147 which was recorded at 2014-01-01 18:41:00
# Ambulance 1 chosen with one-way travel time 0:07:33 (total duration: 0 days 00:35:06)
# Deploying ambulance 1 at time 2014-01-01 18:41:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 3, 6]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 18:49:22
# Current Event: Retire Ambulance
# Coverage: 59.0 %.
# Retiring ambulance 6 at time 2014-01-01 18:49:22
# Busy ambulances:  [0, 1, 3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 19:14:56
# Current Event: Retire Ambulance
# Coverage: 67.0 %.
# Retiring ambulance 3 at time 2014-01-01 19:14:56
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 19:15:00
# Current Event: Retire Ambulance
# Coverage: 68.0 %.
# Retiring ambulance 0 at time 2014-01-01 19:15:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 19:16:06
# Current Event: Retire Ambulance
# Coverage: 90.0 %.
# Retiring ambulance 1 at time 2014-01-01 19:16:06
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 19:39:00
# Current Event: Start Case
# Coverage: 98.0 %.
# Starting case 14 which was recorded at 2014-01-01 19:39:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 19:39:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 19:58:00
# Current Event: Start Case
# Coverage: 82.0 %.
# Starting case 143 which was recorded at 2014-01-01 19:58:00
# Ambulance 1 chosen with one-way travel time 0:13:25 (total duration: 0 days 00:46:50)
# Deploying ambulance 1 at time 2014-01-01 19:58:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 20:03:00
# Current Event: Start Case
# Coverage: 68.0 %.
# Starting case 27 which was recorded at 2014-01-01 20:03:00
# Ambulance 3 chosen with one-way travel time 0:08:04 (total duration: 0 days 00:36:08)
# Deploying ambulance 3 at time 2014-01-01 20:03:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 20:12:00
# Current Event: Start Case
# Coverage: 67.0 %.
# Starting case 133 which was recorded at 2014-01-01 20:12:00
# Ambulance 8 chosen with one-way travel time 0:13:41 (total duration: 0 days 00:47:22)
# Deploying ambulance 8 at time 2014-01-01 20:12:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 3, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 20:17:00
# Current Event: Retire Ambulance
# Coverage: 64.0 %.
# Retiring ambulance 0 at time 2014-01-01 20:17:00
# Busy ambulances:  [1, 3, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 20:19:00
# Current Event: Start Case
# Coverage: 87.0 %.
# Starting case 120 which was recorded at 2014-01-01 20:19:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-01 20:19:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 3, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 20:39:08
# Current Event: Retire Ambulance
# Coverage: 64.0 %.
# Retiring ambulance 3 at time 2014-01-01 20:39:08
# Busy ambulances:  [0, 1, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 20:44:50
# Current Event: Retire Ambulance
# Coverage: 67.0 %.
# Retiring ambulance 1 at time 2014-01-01 20:44:50
# Busy ambulances:  [0, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01 20:57:00
# Current Event: Retire Ambulance
# Coverage: 81.0 %.
# Retiring ambulance 0 at time 2014-01-01 20:57:00
# Busy ambulances:  [8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-01
00
# Current Event: Start Case
# Coverage: 98.0 %.
# Starting case 19 which was recorded at 2014-01-02 05:59:00
# Ambulance 1 chosen with one-way travel time 0:07:33 (total duration: 0 days 00:35:06)
# Deploying ambulance 1 at time 2014-01-02 05:59:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 06:34:06
# Current Event: Retire Ambulance
# Coverage: 90.0 %.
# Retiring ambulance 1 at time 2014-01-02 06:34:06
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 06:52:00
# Current Event: Start Case
# Coverage: 98.0 %.
# Starting case 73 which was recorded at 2014-01-02 06:52:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 06:52:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 07:06:00
# Current Event: Start Case
# Coverage: 82.0 %.
# Starting case 41 which was recorded at 2014-01-02 07:06:00
# Ambulance 3 chosen with one-way travel time 0:10:58 (total duration: 0 days 00:41:56)
# Deploying ambulance 3 at time 2014-01-02 07:06:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 07:06:00
# Current Event: Start Case
# Coverage: 81.0 %.
# Starting case 81 which was recorded at 2014-01-02 07:06:00
# Ambulance 8 chosen with one-way travel time 0:13:41 (total duration: 0 days 00:47:22)
# Deploying ambulance 8 at time 2014-01-02 07:06:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 07:30:00
# Current Event: Retire Ambulance
# Coverage: 78.0 %.
# Retiring ambulance 0 at time 2014-01-02 07:30:00
# Busy ambulances:  [3, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 07:32:00
# Current Event: Start Case
# Coverage: 95.0 %.
# Starting case 80 which was recorded at 2014-01-02 07:32:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 07:32:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 07:34:00
# Current Event: Start Case
# Coverage: 78.0 %.
# Starting case 92 which was recorded at 2014-01-02 07:34:00
# Ambulance 6 chosen with one-way travel time 0:14:11 (total duration: 0 days 00:48:22)
# Deploying ambulance 6 at time 2014-01-02 07:34:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 6, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 07:47:56
# Current Event: Retire Ambulance
# Coverage: 70.0 %.
# Retiring ambulance 3 at time 2014-01-02 07:47:56
# Busy ambulances:  [0, 6, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 07:53:22
# Current Event: Retire Ambulance
# Coverage: 76.0 %.
# Retiring ambulance 8 at time 2014-01-02 07:53:22
# Busy ambulances:  [0, 6]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 08:10:00
# Current Event: Retire Ambulance
# Coverage: 77.0 %.
# Retiring ambulance 0 at time 2014-01-02 08:10:00
# Busy ambulances:  [6]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 08:22:22
# Current Event: Retire Ambulance
# Coverage: 94.0 %.
# Retiring ambulance 6 at time 2014-01-02 08:22:22
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 08:28:00
# Current Event: Start Case
# Coverage: 98.0 %.
# Starting case 42 which was recorded at 2014-01-02 08:28:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 08:28:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 08:30:00
# Current Event: Start Case
# Coverage: 82.0 %.
# Starting case 40 which was recorded at 2014-01-02 08:30:00
# Ambulance 3 chosen with one-way travel time 0:10:58 (total duration: 0 days 00:41:56)
# Deploying ambulance 3 at time 2014-01-02 08:30:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 08:47:00
# Current Event: Start Case
# Coverage: 81.0 %.
# Starting case 30 which was recorded at 2014-01-02 08:47:00
# Ambulance 8 chosen with one-way travel time 0:13:41 (total duration: 0 days 00:47:22)
# Deploying ambulance 8 at time 2014-01-02 08:47:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 08:57:00
# Current Event: Start Case
# Coverage: 78.0 %.
# Starting case 108 which was recorded at 2014-01-02 08:57:00
# Ambulance 5 chosen with one-way travel time 0:06:42 (total duration: 0 days 00:33:24)
# Deploying ambulance 5 at time 2014-01-02 08:57:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 5, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 09:00:00
# Current Event: Start Case
# Coverage: 74.0 %.
# Starting case 64 which was recorded at 2014-01-02 09:00:00
# Ambulance 6 chosen with one-way travel time 0:14:11 (total duration: 0 days 00:48:22)
# Deploying ambulance 6 at time 2014-01-02 09:00:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 5, 6, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 09:00:00
# Current Event: Start Case
# Coverage: 66.0 %.
# Starting case 21 which was recorded at 2014-01-02 09:00:00
# Ambulance 7 chosen with one-way travel time 0:14:30 (total duration: 0 days 00:49:00)
# Deploying ambulance 7 at time 2014-01-02 09:00:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 5, 6, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 09:06:00
# Current Event: Retire Ambulance
# Coverage: 56.00000000000001 %.
# Retiring ambulance 0 at time 2014-01-02 09:06:00
# Busy ambulances:  [3, 5, 6, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 09:07:00
# Current Event: Start Case
# Coverage: 75.0 %.
# Starting case 91 which was recorded at 2014-01-02 09:07:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-02 09:07:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 5, 6, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 09:11:56
# Current Event: Retire Ambulance
# Coverage: 56.00000000000001 %.
# Retiring ambulance 3 at time 2014-01-02 09:11:56
# Busy ambulances:  [0, 5, 6, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 09:22:00
# Current Event: Start Case
# Coverage: 68.0 %.
# Starting case 53 which was recorded at 2014-01-02 09:22:00
# Ambulance 3 chosen with one-way travel time 0:10:58 (total duration: 0 days 00:41:56)
# Deploying ambulance 3 at time 2014-01-02 09:22:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 5, 6, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 09:30:24
# Current Event: Retire Ambulance
# Coverage: 56.00000000000001 %.
# Retiring ambulance 5 at time 2014-01-02 09:30:24
# Busy ambulances:  [0, 3, 6, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-02 09:34:22
# Current Event: Retire Ambulance
# Coverage: 60.0 %.
# ...
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 2, 4, 7, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 21:17:58
# Current Event: Retire Ambulance
# Coverage: 67.0 %.
# Retiring ambulance 4 at time 2014-01-04 21:17:58
# Busy ambulances:  [0, 2, 7, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 21:20:00
# Current Event: Start Case
# Coverage: 71.0 %.
# Starting case 269 which was recorded at 2014-01-04 21:20:00
# Ambulance 3 chosen with one-way travel time 0:08:04 (total duration: 0 days 00:36:08)
# Deploying ambulance 3 at time 2014-01-04 21:20:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 2, 3, 7, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 21:22:00
# Current Event: Start Case
# Coverage: 70.0 %.
# Starting case 271 which was recorded at 2014-01-04 21:22:00
# Ambulance 8 chosen with one-way travel time 0:13:41 (total duration: 0 days 00:47:22)
# Deploying ambulance 8 at time 2014-01-04 21:22:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 2, 3, 7, 8, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 21:24:48
# Current Event: Retire Ambulance
# Coverage: 60.0 %.
# Retiring ambulance 2 at time 2014-01-04 21:24:48
# Busy ambulances:  [0, 3, 7, 8, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 21:27:30
# Current Event: Retire Ambulance
# Coverage: 68.0 %.
# Retiring ambulance 14 at time 2014-01-04 21:27:30
# Busy ambulances:  [0, 3, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 21:29:00
# Current Event: Start Case
# Coverage: 68.0 %.
# Starting case 276 which was recorded at 2014-01-04 21:29:00
# Ambulance 2 chosen with one-way travel time 0:07:33 (total duration: 0 days 00:35:06)
# Deploying ambulance 2 at time 2014-01-04 21:29:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 2, 3, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 21:37:14
# Current Event: Retire Ambulance
# Coverage: 60.0 %.
# Retiring ambulance 0 at time 2014-01-04 21:37:14
# Busy ambulances:  [2, 3, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 21:44:02
# Current Event: Retire Ambulance
# Coverage: 78.0 %.
# Retiring ambulance 7 at time 2014-01-04 21:44:02
# Busy ambulances:  [2, 3, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 21:51:00
# Current Event: Start Case
# Coverage: 87.0 %.
# Starting case 294 which was recorded at 2014-01-04 21:51:00
# Ambulance 0 chosen with one-way travel time 0:09:38 (total duration: 0 days 00:39:16)
# Deploying ambulance 0 at time 2014-01-04 21:51:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 2, 3, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 21:56:08
# Current Event: Retire Ambulance
# Coverage: 70.0 %.
# Retiring ambulance 3 at time 2014-01-04 21:56:08
# Busy ambulances:  [0, 2, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 22:04:06
# Current Event: Retire Ambulance
# Coverage: 73.0 %.
# Retiring ambulance 2 at time 2014-01-04 22:04:06
# Busy ambulances:  [0, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 22:09:22
# Current Event: Retire Ambulance
# Coverage: 81.0 %.
# Retiring ambulance 8 at time 2014-01-04 22:09:22
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 22:30:16
# Current Event: Retire Ambulance
# Coverage: 82.0 %.
# Retiring ambulance 0 at time 2014-01-04 22:30:16
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 22:57:00
# Current Event: Start Case
# Coverage: 98.0 %.
# Starting case 293 which was recorded at 2014-01-04 22:57:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-04 22:57:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:04:00
# Current Event: Start Case
# Coverage: 82.0 %.
# Starting case 335 which was recorded at 2014-01-04 23:04:00
# Ambulance 3 chosen with one-way travel time 0:10:58 (total duration: 0 days 00:41:56)
# Deploying ambulance 3 at time 2014-01-04 23:04:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:12:00
# Current Event: Start Case
# Coverage: 81.0 %.
# Starting case 262 which was recorded at 2014-01-04 23:12:00
# Ambulance 8 chosen with one-way travel time 0:13:41 (total duration: 0 days 00:47:22)
# Deploying ambulance 8 at time 2014-01-04 23:12:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:14:00
# Current Event: Start Case
# Coverage: 78.0 %.
# Starting case 272 which was recorded at 2014-01-04 23:14:00
# Ambulance 5 chosen with one-way travel time 0:06:42 (total duration: 0 days 00:33:24)
# Deploying ambulance 5 at time 2014-01-04 23:14:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 5, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:14:00
# Current Event: Start Case
# Coverage: 74.0 %.
# Starting case 244 which was recorded at 2014-01-04 23:14:00
# Ambulance 6 chosen with one-way travel time 0:14:11 (total duration: 0 days 00:48:22)
# Deploying ambulance 6 at time 2014-01-04 23:14:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 5, 6, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:17:00
# Current Event: Start Case
# Coverage: 66.0 %.
# Starting case 371 which was recorded at 2014-01-04 23:17:00
# Ambulance 7 chosen with one-way travel time 0:14:30 (total duration: 0 days 00:49:00)
# Deploying ambulance 7 at time 2014-01-04 23:17:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3, 5, 6, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:20:00
# Current Event: Start Case
# Coverage: 56.00000000000001 %.
# Starting case 253 which was recorded at 2014-01-04 23:20:00
# Ambulance 1 chosen with one-way travel time 0:18:05 (total duration: 0 days 00:56:10)
# Deploying ambulance 1 at time 2014-01-04 23:20:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 3, 5, 6, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:25:00
# Current Event: Start Case
# Coverage: 39.0 %.
# Starting case 218 which was recorded at 2014-01-04 23:25:00
# Ambulance 14 chosen with one-way travel time 0:04:15 (total duration: 0 days 00:28:30)
# Deploying ambulance 14 at time 2014-01-04 23:25:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 3, 5, 6, 7, 8, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:28:00
# Current Event: Start Case
# Coverage: 39.0 %.
# Starting case 290 which was recorded at 2014-01-04 23:28:00
# Ambulance 2 chosen with one-way travel time 0:09:01 (total duration: 0 days 00:38:02)
# Deploying ambulance 2 at time 2014-01-04 23:28:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 2, 3, 5, 6, 7, 8, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:35:00
# Current Event: Retire Ambulance
# Coverage: 31.0 %.
# Retiring ambulance 0 at time 2014-01-04 23:35:00
# Busy ambulances:  [1, 2, 3, 5, 6, 7, 8, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:36:00
# Current Event: Start Case
# Coverage: 59.0 %.
# Starting case 299 which was recorded at 2014-01-04 23:36:00
# Ambulance 0 chosen with one-way travel time 0:06:21 (total duration: 0 days 00:32:42)
# Deploying ambulance 0 at time 2014-01-04 23:36:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 2, 3, 5, 6, 7, 8, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:45:56
# Current Event: Retire Ambulance
# Coverage: 31.0 %.
# Retiring ambulance 3 at time 2014-01-04 23:45:56
# Busy ambulances:  [0, 1, 2, 5, 6, 7, 8, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:47:24
# Current Event: Retire Ambulance
# Coverage: 43.0 %.
# Retiring ambulance 5 at time 2014-01-04 23:47:24
# Busy ambulances:  [0, 1, 2, 6, 7, 8, 14]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:53:30
# Current Event: Retire Ambulance
# Coverage: 50.0 %.
# Retiring ambulance 14 at time 2014-01-04 23:53:30
# Busy ambulances:  [0, 1, 2, 6, 7, 8]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-04 23:59:22
# Current Event: Retire Ambulance
# Coverage: 50.0 %.
# Retiring ambulance 8 at time 2014-01-04 23:59:22
# Busy ambulances:  [0, 1, 2, 6, 7]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 00:02:22
# Current Event: Retire Ambulance
# Coverage: 52.0 %.
# Retiring ambulance 6 at time 2014-01-05 00:02:22
# Busy ambulances:  [0, 1, 2, 7]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 00:06:00
# Current Event: Retire Ambulance
# Coverage: 56.99999999999999 %.
# Retiring ambulance 7 at time 2014-01-05 00:06:00
# Busy ambulances:  [0, 1, 2]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 00:06:02
# Current Event: Retire Ambulance
# Coverage: 60.0 %.
# Retiring ambulance 2 at time 2014-01-05 00:06:02
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 00:08:42
# Current Event: Retire Ambulance
# Coverage: 68.0 %.
# Retiring ambulance 0 at time 2014-01-05 00:08:42
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 00:16:10
# Current Event: Retire Ambulance
# Coverage: 90.0 %.
# Retiring ambulance 1 at time 2014-01-05 00:16:10
# Busy ambulances:  []
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 00:56:00
# Current Event: Start Case
# Coverage: 98.0 %.
# Starting case 278 which was recorded at 2014-01-05 00:56:00
# Ambulance 10 chosen with one-way travel time 0:07:32 (total duration: 0 days 00:35:04)
# Deploying ambulance 10 at time 2014-01-05 00:56:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [10]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 01:04:00
# Current Event: Start Case
# Coverage: 97.0 %.
# Starting case 251 which was recorded at 2014-01-05 01:04:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-05 01:04:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 10]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 01:13:00
# Current Event: Start Case
# Coverage: 81.0 %.
# Starting case 372 which was recorded at 2014-01-05 01:13:00
# Ambulance 1 chosen with one-way travel time 0:16:13 (total duration: 0 days 00:52:26)
# Deploying ambulance 1 at time 2014-01-05 01:13:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 10]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 01:31:04
# Current Event: Retire Ambulance
# Coverage: 67.0 %.
# Retiring ambulance 10 at time 2014-01-05 01:31:04
# Busy ambulances:  [0, 1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 01:42:00
# Current Event: Retire Ambulance
# Coverage: 68.0 %.
# Retiring ambulance 0 at time 2014-01-05 01:42:00
# Busy ambulances:  [1]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 01:42:00
# Current Event: Start Case
# Coverage: 90.0 %.
# Starting case 233 which was recorded at 2014-01-05 01:42:00
# Ambulance 3 chosen with one-way travel time 0:08:04 (total duration: 0 days 00:36:08)
# Deploying ambulance 3 at time 2014-01-05 01:42:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [1, 3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 02:05:26
# Current Event: Retire Ambulance
# Coverage: 89.0 %.
# Retiring ambulance 1 at time 2014-01-05 02:05:26
# Busy ambulances:  [3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 02:15:00
# Current Event: Start Case
# Coverage: 97.0 %.
# Starting case 279 which was recorded at 2014-01-05 02:15:00
# Ambulance 0 chosen with one-way travel time 0:09:38 (total duration: 0 days 00:39:16)
# Deploying ambulance 0 at time 2014-01-05 02:15:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 02:18:08
# Current Event: Retire Ambulance
# Coverage: 81.0 %.
# Retiring ambulance 3 at time 2014-01-05 02:18:08
# Busy ambulances:  [0]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 02:26:00
# Current Event: Start Case
# Coverage: 82.0 %.
# Starting case 266 which was recorded at 2014-01-05 02:26:00
# Ambulance 3 chosen with one-way travel time 0:10:58 (total duration: 0 days 00:41:56)
# Deploying ambulance 3 at time 2014-01-05 02:26:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 02:54:16
# Current Event: Retire Ambulance
# Coverage: 81.0 %.
# Retiring ambulance 0 at time 2014-01-05 02:54:16
# Busy ambulances:  [3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 02:58:00
# Current Event: Start Case
# Coverage: 97.0 %.
# Starting case 337 which was recorded at 2014-01-05 02:58:00
# Ambulance 1 chosen with one-way travel time 0:09:05 (total duration: 0 days 00:38:10)
# Deploying ambulance 1 at time 2014-01-05 02:58:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [1, 3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 03:00:00
# Current Event: Start Case
# Coverage: 89.0 %.
# Starting case 245 which was recorded at 2014-01-05 03:00:00
# Ambulance 0 chosen with one-way travel time 0:09:00 (total duration: 0 days 00:38:00)
# Deploying ambulance 0 at time 2014-01-05 03:00:00
# Delay on this case: 0 days 00:00:00
# Busy ambulances:  [0, 1, 3]
# Pending cases:  []
# ========================================================================
#
# Current Time: 2014-01-05 03:07:56
# Current Event: Retire Ambulance
